# %%
# Escreva um programa em Python que imprima a letra A como ilustrado abaixo
#   ***
#  *   *
#  *   *
#  *****
#  *   *
#  *   *
#  *   *
import time
# print('  *** ')
# print(' *   *')
# print(' *   *')
# print(' *****')
# print(' *   *')
# print(' *   *')
# print(' *   *')

linha=0
for linha in range(7):
  if linha==0:
    print('  *** ')
    linha += 1
  elif linha in (1,2,4,5,6):
    print(' *   *')
    linha += 1
  elif linha==3:
    print(' '+5*'*')
    linha += 1
  else:
    break

time.sleep(0.8)
# Out:
#   ***
#  *   *
#  *   *
#  *****
#  *   *
#  *   *
#  *   *
#   ***
#  *   *
#  *   *
#  *****
#  *   *
#  *   *
#  *   *
