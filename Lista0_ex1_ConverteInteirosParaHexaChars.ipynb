# %%
# 1-[Dados] Convertendo inteiros para hexa e chars
# 1097167471 Aero
# 12345768 �a�
import time
import codecs

entrada= int(input())
# entrada=1097167471
# print(f'Entrada:\n{entrada}')
numero_hexadecimal = format(entrada, 'x')                   # formatar o inteiro para um hexadecimal
# print(numero_hexadecimal)
cadeia_de_bytes = bytes.fromhex(numero_hexadecimal)         # converter hexadecimal em uma cadeia de bytes
# print(cadeia_de_bytes)
saida = cadeia_de_bytes.decode('utf-8',errors='replace')    # transformar a cadeia de bytes em cadeia de caracteres
# print(f'Saída:\n{saida}')
print(saida)

time.sleep(0.8)
# Out:
# 12345768
# �a�
