# %% [markdown]
# Tipos de Dados

# %%
print(type(2))
print(type(-2))
print(type('2'))
print(type(2.5))
print(type([1,2,3]))
print(type(('a',1.2,3)))
print(type('João'))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'list'>
# <class 'tuple'>
# <class 'str'>

# %% [markdown]
# Variáveis

# %%
# print(f'Variáveis mudam de valor e tipo dinamicamente\n')
# a=2
# print(a,type(a))
# a='João'
# print(a,type(a))
# a=-2
# print(a,type(a))

# print(f'\nFormatando Saída\n')
# x,y = 'joao',2.5
# print(x,y)
# print(f'Ex1:{x} é uma {type(x)} e {y} é um {type(y)}')
# print(f'Ex2:{x=} é uma {type(x)} e {y=} é um {type(y)}')
# print('Ex3:{0} é uma {1} e {2} é um {3}'.format(x, type(x),y,type(y)))
# import math
# s= f'O valor aproximado de pi é {math.pi:.6f}.'
# print(s)

# print(f'\nOperações básicas\n')
# a,b=5,2
# print(f'{a}+{b}={a+b}\n{a}*{b}={a*b}\n{a}/{b}={a/b}\n{a}//{b}={a//b}')
# print(f'{a}%{b}={a%b}\n{a}**{b}={a**b}')
# print(f'{a}=={b}:{a==b}',end=",")
# print(f'\n{a}>{b}:{a>b}\n{a}<{b}:{a<b}\n{a}>={b}:{a>=b}\n{a}<={b}:{a<=b}\n{a}!={b}:{a!=b}')

# print(f'\nNotação curta\n')
# a,b=5,2
# a+=b #a=a+b
# print(a)
# a*=b #a=a*b
# print(a)

print(f'\nAtribuição de valores\n')
x,y = 2,3
print(f'{x=},{y=}')
x, y = y,x
print(f'{x=},{y=}')
alunos=['joao','maria','ana']
print(alunos, alunos[0],alunos[2])
# Out:
# Atribuição de valores
#
# x=2,y=3
# x=3,y=2
# ['joao', 'maria', 'ana'] joao ana

# %% [markdown]
# #Strings
# ![Strings - Fig1.png](data:image/png;base64,...)

# %%
# print(f'\nCase sensitive\n')
# st= 'Maria'
# print("Ana" != 'ana')
# print("ana" > 'Ana')
# print("João" > 'Ana')

# st='Maria'
# print(f'\nÍndices e fatiamento st=Maria \n')
# print("st[1:4] =>",st[1:4])
# print("st[::2] =>",st[::2])
# print("st[1:4:2] =>",st[1:4:2])
# print("st[: : ] =>",st[: : ])
# print("st[0:len(st):1] =>",st[0:len(st):1])

# st='Maria'
# print(f'\nÍndices em ordem inversa Maria\n')
# print("st[-1:]=>",st[-1:])
# print("st[-3:]=>",st[-3:])
# print("st[-4:]=>",st[-4:])
# print("st[-len(st):]=>",st[-len(st):])
# print("st[: : -1] =>",st[: : -1])
# print("st[-1:- (len(st)+1) : -1] =>",st[-1:- (len(st)+1) : -1])
# print("st[-1:-6:-1] =>",st[-1:-6:-1])
# print("st[-1:-4:-1] =>",st[-1:-4:-1])
# Out:
# Índices em ordem inversa Maria
#
# st[-1:]=> a
# st[-3:]=> ria
# st[-4:]=> aria
# st[-len(st):]=> Maria
# st[: : -1] => airaM
# st[-1:- (len(st)+1) : -1] => airaM
# st[-1:-6:-1] => airaM
# st[-1:-4:-1] => air

# %%
# print(f'\nOperadores\n')

# s1="olá"
# s2="mundo"
# s3=s1+s2
# print(s3)
# s3=s1+" "+s2+"!"
# print(s3)
# print(s1*3)
# print(s1 in s3)
# print(s2 in s3)
# print('oi' in s3)
# print('oi' not in s3)
# Out:
# Operadores
#
# olámundo
# olá mundo!
# oláoláolá
# True
# True
# False
# True

# %%
# print(f'\nAlgumas funções\n')

# print(f'{ord("a")=},{ord("A")=}')
# #print(ord('AB'))
# print(f'{ord("@")=},{ord("#")=}')
# print(f'{chr(97)=},{chr(65)=},{chr(64)=},{chr(35)=}')
# print(f'{chr(190)=}')
# print(f'{len("Todos devem estudar para a prova, senão......")=}')
# x=2.55
# print(f'valor float x={x}')
# print(f'string x={str(x)}')
# y=str(x)
# y=y[0]+','+y[2:len(y)]
# print(f'{y=}')
# y=y[0]+','+y[2:]
# print(f'{y=}')
# Out:
# Algumas funções
#
# ord("a")=97,ord("A")=65
# ord("@")=64,ord("#")=35
# chr(97)='a',chr(65)='A',chr(64)='@',chr(35)='#'
# chr(190)='¾'
# len("Todos devem estudar para a prova, senão......")=45
# valor float x=2.55
# string x=2.55
# y='2,55'
# y='2,55'

# %%
print(f'\nAlgumas funções\n')

s="JoAo Da SILva"
print(s)
print(f'{s.lower()=}')
print(f'{s.upper()=}')
print(f'{s.swapcase()=}')
print(f'{s.title()=}')
print(f'{s.capitalize()=}')
print(f'{s.count("Ao")=}')
print(f'{s.count("Ao",3,9)=}')
print(f'{s.find("SI")=}')
print(s)
# Out:
# Algumas funções
#
# JoAo Da SILva
# s.lower()='joao da silva'
# s.upper()='JOAO DA SILVA'
# s.swapcase()='jOaO dA silVA'
# s.title()='Joao Da Silva'
# s.capitalize()='Joao da silva'
# s.count("Ao")=1
# s.count("Ao",3,9)=0
# s.find("SI")=8
# JoAo Da SILva

# %% [markdown]
# # Saída de dados

# %%
# nome='joao'
# idade=10
# peso=30.5
# print(f'Nome:{nome} Idade:{idade}  Peso: {peso:.3f}')
# Out:
# Nome:joao Idade:10  Peso: 30.500

# %% [markdown]
# #Entrada de Dados

# %%
# print('\nExemplo 1\n')
# nome,idade,peso=input().split()
# idade=int(idade)
# peso=float(peso)
# print(f'{nome=},{idade=},{peso=}')
# print(f'{peso*idade=}')

# print('\nExemplo 2')
# s='Joao,20,78,1.88'
# nome,idade,peso,altura= s.split(',')
# print(f'{nome=},{idade=},{peso=},{altura=}')

# print('\nExemplo 3')
# s='Joao#20#78#1.88'
# nome,idade,peso,altura= s.split('#')
# print(f'{nome=},{idade=},{peso=},{altura=}')

# print('\nExemplo 4')
# s='Joao#20#78#1.88'
# nome,idade,restante= s.split('#',2)
# print(f'{nome=},{idade=},{restante=}')
# Out:
# Exemplo 4
# nome='Joao',idade='20',restante='78#1.88'

# %%
print('\nmap()\n')
x,y= map(int, input().split())
print(f'{x=},{y=}')
x, y = map(float, input().split())
print(f'{x=},{y=}')
# Out:
# map()
#
# 10 20
# x=10,y=20
# 1.85 10
# x=1.85,y=10.0
